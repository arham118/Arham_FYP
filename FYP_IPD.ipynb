# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#reads each file into its relevant dataframes

df2025 = pd.read_csv('/2025.csv')
df2024 = pd.read_csv('/2024.csv')
df2023 = pd.read_csv('/2023.csv')
df2022 = pd.read_csv('/2022.csv')

# %%
#display the first few rows of the dataframe 2025

df2025.head()
# Out:
#      month  seller_id shop_account_code shop_account_name industry_name  \
# 0  2025-01         87           LK1002H     kumara-lakmal            EL
# 1  2025-01         87           LK1002H     kumara-lakmal       Fashion
# 2  2025-01         87           LK1002H     kumara-lakmal            GM
# 3  2025-01        236           LK1006R    mobile-lankans          FMCG
# 4  2025-01        236           LK1006R    mobile-lankans            GM
#
#       venture_category1_name_en venture_category2_name_en  \
# 0             Mobiles & Tablets        Mobile Accessories
# 1  Watches Sunglasses Jewellery                   Watches
# 2                        Motors                Automotive
# 3               Health & Beauty              Beauty Tools
# 4             Sports & Outdoors        Exercise & Fitness
#
#   venture_category3_name_en      venture_category4_name_en  \
# 0             Wall Chargers                            NaN
# 1                    Unisex                         Sports
# ...

# %%
#display the first few rows of the dataframe 2024

df2024.head()
# Out:
#      month  seller_id shop_account_code shop_account_name industry_name  \
# 0  2024-01         34           LK1000Z           Catchme            GM
# 1  2024-01        236           LK1006R    mobile-lankans            EL
# 2  2024-01        276           LK1007W      Supersavings          FMCG
# 3  2024-01        276           LK1007W      Supersavings            GM
# 4  2024-01       1709           LK101DU            BRADOO            GM
#
#   venture_category1_name_en       venture_category2_name_en  \
# 0         Sports & Outdoors              Outdoor Recreation
# 1         Mobiles & Tablets              Mobile Accessories
# 2             Mother & Baby              Baby Personal Care
# 3          Kitchen & Dining                Kitchen Utensils
# 4              Toys & Games  Remote Control & Play Vehicles
#
#   venture_category3_name_en venture_category4_name_en  \
# 0                   Cycling          Cycling Clothing
# 1       Cables & Converters                       NaN
# ...

# %%
#display the first few rows of the dataframe 2023

df2023.head()
# Out:
#      month  seller_id shop_account_code          shop_account_name  \
# 0  2023-01         12           LK1000C  Brantel Lanka Pvt Limited
# 1  2023-01         12           LK1000C  Brantel Lanka Pvt Limited
# 2  2023-01         34           LK1000Z                    Catchme
# 3  2023-01         34           LK1000Z                    Catchme
# 4  2023-01         34           LK1000Z                    Catchme
#
#   industry_name venture_category1_name_en venture_category2_name_en  \
# 0            EL         Mobiles & Tablets            Feature Phones
# 1            EL         Mobiles & Tablets                   Tablets
# 2            EL           Home Appliances  Small Kitchen Appliances
# 3            EL         Mobiles & Tablets        Mobile Accessories
# 4          FMCG                 Groceries                 Beverages
#
#   venture_category3_name_en venture_category4_name_en  \
# 0                       NaN                       NaN
# ...

# %%
#display the first few rows of the dataframe 2022

df2022.head()
# Out:
#      month  seller_id shop_account_code shop_account_name industry_name  \
# 0  2022-01        236           LK1006R    mobile-lankans            GM
# 1  2022-01        276           LK1007W      Supersavings            GM
# 2  2022-01        276           LK1007W      Supersavings            GM
# 3  2022-01       1708           LK101DT           ToHayie            GM
# 4  2022-01       1708           LK101DT           ToHayie            GM
#
#   venture_category1_name_en venture_category2_name_en  \
# 0         Furniture & Decor                 Furniture
# 1         Furniture & Decor                 Furniture
# 2          Kitchen & Dining                Dinnerware
# 3                    Motors                Automotive
# 4                    Motors                Automotive
#
#   venture_category3_name_en venture_category4_name_en  \
# 0     Living Room Furniture       Sofa Covers & Slips
# 1     Living Room Furniture                     Sofas
# ...

# %%
# i used this query to understand the dataset better, by knowing how many columns and rows the dataset has, how many missing values are found, what are the data types of the columns and finally got a statistical summary for each dataset

df2022.shape
df2022.info()
df2022.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298435 entries, 0 to 298434
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   month                      298435 non-null  object
#  1   seller_id                  298435 non-null  int64
#  2   shop_account_code          298435 non-null  object
#  3   shop_account_name          298435 non-null  object
#  4   industry_name              298181 non-null  object
#  5   venture_category1_name_en  298435 non-null  object
#  6   venture_category2_name_en  298435 non-null  object
#  7   venture_category3_name_en  293419 non-null  object
#  8   venture_category4_name_en  150959 non-null  object
#  9   venture_category5_name_en  38842 non-null   object
#  10  venture_category6_name_en  2536 non-null    object
#  11  business_area              298434 non-null  object
#  12  business_type              298434 non-null  object
# ...

# %%
# i used this query to understand the dataset better, by knowing how many columns and rows the dataset has, how many missing values are found, what are the data types of the columns and finally got a statistical summary for each dataset

df2023.shape
df2023.info()
df2023.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300008 entries, 0 to 300007
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   month                      300008 non-null  object
#  1   seller_id                  300008 non-null  int64
#  2   shop_account_code          300008 non-null  object
#  3   shop_account_name          300008 non-null  object
#  4   industry_name              299841 non-null  object
#  5   venture_category1_name_en  300008 non-null  object
#  6   venture_category2_name_en  300007 non-null  object
#  7   venture_category3_name_en  295229 non-null  object
#  8   venture_category4_name_en  152473 non-null  object
#  9   venture_category5_name_en  38747 non-null   object
#  10  venture_category6_name_en  2769 non-null    object
#  11  business_area              300007 non-null  object
#  12  business_type              300007 non-null  object
# ...

# %%
# i used this query to understand the dataset better, by knowing how many columns and rows the dataset has, how many missing values are found, what are the data types of the columns and finally got a statistical summary for each dataset

df2024.shape
df2024.info()
df2024.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280323 entries, 0 to 280322
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   month                      280323 non-null  object
#  1   seller_id                  280323 non-null  int64
#  2   shop_account_code          280322 non-null  object
#  3   shop_account_name          280322 non-null  object
#  4   industry_name              280124 non-null  object
#  5   venture_category1_name_en  280284 non-null  object
#  6   venture_category2_name_en  280284 non-null  object
#  7   venture_category3_name_en  276905 non-null  object
#  8   venture_category4_name_en  145398 non-null  object
#  9   venture_category5_name_en  36245 non-null   object
#  10  venture_category6_name_en  2354 non-null    object
#  11  business_area              280322 non-null  object
#  12  business_type              280322 non-null  object
# ...

# %%
# i used this query to understand the dataset better, by knowing how many columns and rows the dataset has, how many missing values are found, what are the data types of the columns and finally got a statistical summary for each dataset

df2025.shape
df2025.info()
df2025.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80086 entries, 0 to 80085
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      80086 non-null  object
#  1   seller_id                  80086 non-null  int64
#  2   shop_account_code          80086 non-null  object
#  3   shop_account_name          80086 non-null  object
#  4   industry_name              80032 non-null  object
#  5   venture_category1_name_en  80076 non-null  object
#  6   venture_category2_name_en  80076 non-null  object
#  7   venture_category3_name_en  79126 non-null  object
#  8   venture_category4_name_en  41245 non-null  object
#  9   venture_category5_name_en  10104 non-null  object
#  10  venture_category6_name_en  634 non-null    object
#  11  business_area              80086 non-null  object
#  12  business_type              80086 non-null  object
# ...

# %%
#counting missing values in each column for df2022

df2022.isnull().sum()
# Out:
# month                             0
# seller_id                         0
# shop_account_code                 0
# shop_account_name                 0
# industry_name                   254
# venture_category1_name_en         0
# venture_category2_name_en         0
# venture_category3_name_en      5016
# venture_category4_name_en    147476
# venture_category5_name_en    259593
# venture_category6_name_en    295899
# business_area                     1
# business_type                     1
# gmv                               1
# nmv                               1
# orders                            1
# items                             1
# buyers                            1
# pdp_uv                       298435
# pdp_pv                       298435
# dtype: int64

# %%
#counting missing values in each column for df2023

df2023.isnull().sum()
# Out:
# month                             0
# seller_id                         0
# shop_account_code                 0
# shop_account_name                 0
# industry_name                   167
# venture_category1_name_en         0
# venture_category2_name_en         1
# venture_category3_name_en      4779
# venture_category4_name_en    147535
# venture_category5_name_en    261261
# venture_category6_name_en    297239
# business_area                     1
# business_type                     1
# gmv                               1
# nmv                               1
# orders                            1
# items                             1
# buyers                            1
# pdp_uv                       300008
# pdp_pv                       300008
# dtype: int64

# %%
#counting missing values in each column for df2024

df2024.isnull().sum()
# Out:
# month                             0
# seller_id                         0
# shop_account_code                 1
# shop_account_name                 1
# industry_name                   199
# venture_category1_name_en        39
# venture_category2_name_en        39
# venture_category3_name_en      3418
# venture_category4_name_en    134925
# venture_category5_name_en    244078
# venture_category6_name_en    277969
# business_area                     1
# business_type                     1
# gmv                               1
# nmv                               1
# orders                            1
# items                             1
# buyers                            1
# pdp_uv                       280323
# pdp_pv                       280323
# dtype: int64

# %%
#counting missing values in each column for df2025

df2025.isnull().sum()
# Out:
# month                            0
# seller_id                        0
# shop_account_code                0
# shop_account_name                0
# industry_name                   54
# venture_category1_name_en       10
# venture_category2_name_en       10
# venture_category3_name_en      960
# venture_category4_name_en    38841
# venture_category5_name_en    69982
# venture_category6_name_en    79452
# business_area                    0
# business_type                    0
# gmv                              0
# nmv                              0
# orders                           0
# items                            0
# buyers                           0
# pdp_uv                       80086
# pdp_pv                       80086
# dtype: int64

# %%
#Drop the columns which is not required.

df2022 = df2022.drop(df2022.columns[8], axis=1)
df2023 = df2023.drop(df2023.columns[8], axis=1)
df2024 = df2024.drop(df2024.columns[8], axis=1)
df2025 = df2025.drop(df2025.columns[8], axis=1)

# %%
df2022 = df2022.drop(df2022.columns[8], axis=1)
df2022.head()
# Out:
#      month  seller_id shop_account_code shop_account_name industry_name  \
# 0  2022-01        236           LK1006R    mobile-lankans            GM
# 1  2022-01        276           LK1007W      Supersavings            GM
# 2  2022-01        276           LK1007W      Supersavings            GM
# 3  2022-01       1708           LK101DT           ToHayie            GM
# 4  2022-01       1708           LK101DT           ToHayie            GM
#
#   venture_category1_name_en venture_category2_name_en  \
# 0         Furniture & Decor                 Furniture
# 1         Furniture & Decor                 Furniture
# 2          Kitchen & Dining                Dinnerware
# 3                    Motors                Automotive
# 4                    Motors                Automotive
#
#   venture_category3_name_en venture_category6_name_en business_area  \
# 0     Living Room Furniture                       NaN   Marketplace
# ...

# %%
df2023 = df2023.drop(df2023.columns[8], axis=1)
df2023.head()
# Out:
#      month  seller_id shop_account_code          shop_account_name  \
# 0  2023-01         12           LK1000C  Brantel Lanka Pvt Limited
# 1  2023-01         12           LK1000C  Brantel Lanka Pvt Limited
# 2  2023-01         34           LK1000Z                    Catchme
# 3  2023-01         34           LK1000Z                    Catchme
# 4  2023-01         34           LK1000Z                    Catchme
#
#   industry_name venture_category1_name_en venture_category2_name_en  \
# 0            EL         Mobiles & Tablets            Feature Phones
# 1            EL         Mobiles & Tablets                   Tablets
# 2            EL           Home Appliances  Small Kitchen Appliances
# 3            EL         Mobiles & Tablets        Mobile Accessories
# 4          FMCG                 Groceries                 Beverages
#
#   venture_category3_name_en venture_category6_name_en business_area  \
# 0                       NaN                       NaN   Marketplace
# ...

# %%
df2024 = df2024.drop(df2024.columns[8], axis=1)
df2024.head()
# Out:
#      month  seller_id shop_account_code shop_account_name industry_name  \
# 0  2024-01         34           LK1000Z           Catchme            GM
# 1  2024-01        236           LK1006R    mobile-lankans            EL
# 2  2024-01        276           LK1007W      Supersavings          FMCG
# 3  2024-01        276           LK1007W      Supersavings            GM
# 4  2024-01       1709           LK101DU            BRADOO            GM
#
#   venture_category1_name_en       venture_category2_name_en  \
# 0         Sports & Outdoors              Outdoor Recreation
# 1         Mobiles & Tablets              Mobile Accessories
# 2             Mother & Baby              Baby Personal Care
# 3          Kitchen & Dining                Kitchen Utensils
# 4              Toys & Games  Remote Control & Play Vehicles
#
#   venture_category3_name_en venture_category6_name_en business_area  \
# 0                   Cycling                       NaN   Marketplace
# ...

# %%
df2025 = df2025.drop(df2025.columns[8], axis=1)
df2025.head()
# Out:
#      month  seller_id shop_account_code shop_account_name industry_name  \
# 0  2025-01         87           LK1002H     kumara-lakmal            EL
# 1  2025-01         87           LK1002H     kumara-lakmal       Fashion
# 2  2025-01         87           LK1002H     kumara-lakmal            GM
# 3  2025-01        236           LK1006R    mobile-lankans          FMCG
# 4  2025-01        236           LK1006R    mobile-lankans            GM
#
#       venture_category1_name_en venture_category2_name_en  \
# 0             Mobiles & Tablets        Mobile Accessories
# 1  Watches Sunglasses Jewellery                   Watches
# 2                        Motors                Automotive
# 3               Health & Beauty              Beauty Tools
# 4             Sports & Outdoors        Exercise & Fitness
#
#   venture_category3_name_en venture_category6_name_en business_area  \
# 0             Wall Chargers                       NaN   Marketplace
# ...

# %%
# used to chek for duplicate rows and remove them
df2022.duplicated().sum()
df2022 = df2022.drop_duplicates()

# %%
# used to chek for duplicate rows and remove them

df2023.duplicated().sum()
df2023 = df2023.drop_duplicates()

# %%
# used to chek for duplicate rows and remove them

df2024.duplicated().sum()
df2024 = df2024.drop_duplicates()

# %%
# used to chek for duplicate rows and remove them

df2025.duplicated().sum()
df2025 = df2025.drop_duplicates()

# %%
# Converting the 'month' column to datetime format
df2022['month'] = pd.to_datetime(df2022['month'])
df2023['month'] = pd.to_datetime(df2023['month'])
df2024['month'] = pd.to_datetime(df2024['month'])
df2025['month'] = pd.to_datetime(df2025['month'])
